# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# ! pip install citipy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key
# import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=2000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=2000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
base_url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + weather_api_key +  "&q="
base_url
response = requests.get(base_url).json()
response
# Out:
# {'cod': '400', 'message': 'Nothing to geocode'}

# %%
# {'coord': {'lon': -79.2353, 'lat': 42.097},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 287.52,
#   'feels_like': 283.83,
#   'temp_min': 285.37,
#   'temp_max': 288.71,
#   'pressure': 1011,
#   'humidity': 72},
#  'visibility': 10000,
#  'wind': {'speed': 5.1, 'deg': 171, 'gust': 12.81},
#  'clouds': {'all': 20},
#  'dt': 1616634795,
#  'sys': {'type': 1,
#   'id': 4588,
#   'country': 'US',
#   'sunrise': 1616584370,
#   'sunset': 1616628796},
#  'timezone': -14400,
#  'id': 5122534,
#  'name': 'Jamestown',
#  'cod': 200}

# %%
# Starting URL for Weather Map API Call

city_info = []
# temps = []
# humid = []
# cloudiness = []
# wind_speed = []
# lats = []

#create query url
for city in cities:
    query = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key + "&q=" + city
    response = requests.get(query).json()
    
    try:
        
        name = response['name']
        
        temp = response['main']['temp_max']

        hum = response['main']['humidity']
       
        cloud = response['clouds']['all']
        
        wind = response['wind']['speed']
        
        lon = response['coord']['lon']
        
        lat = response['coord']['lat']
        
        city_info.append({"City Name": name, "Temperature": temp, "Humidity": hum, "Cloudiness": cloud, "Wind": wind, "Longitude": lon, "Latitude": lat})
        
    except KeyError:
        print("City is not found")
        
city_info
# Out:
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# City is not found
# [{'City Name': 'Anloga',
#   'Temperature': 71.6,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind': 17.27,
#   'Longitude': 0.8973,
#   'Latitude': 5.7947},
#  {'City Name': 'Opuwo',
#   'Temperature': 73.15,
#   'Humidity': 39,
#   'Cloudiness': 81,
#   'Wind': 3.27,
#   'Longitude': 13.84,
#   'Latitude': -18.0607},
#  {'City Name': 'Vila Franca do Campo',
#   'Temperature': 59,
#   'Humidity': 82,
#   'Cloudiness': 40,
#   'Wind': 16.11,
#   'Longitude': -25.4333,
#   'Latitude': 37.7167},
#  {'City Name': 'Qeshm',
#   'Temperature': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 29,
#   'Wind': 6.91,
#   'Longitude': 56.2719,
#   'Latitude': 26.9581},
#  {'City Name': 'Kolín',
#   'Temperature': 48.2,
#   'Humidity': 49,
#   'Cloudiness': 0,
#   'Wind': 5.75,
#   'Longitude': 15.2006,
#   'Latitude': 50.0281},
#  {'City Name': 'Bambous Virieux',
#   'Temperature': 79,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind': 17.27,
#   'Longitude': 57.7575,
#   'Latitude': -20.3428},
#  {'City Name': 'Port Alfred',
#   'Temperature': 67.14,
#   'Humidity': 85,
#   'Cloudiness': 53,
#   'Wind': 8.88,
#   'Longitude': 26.891,
#   'Latitude': -33.5906},
#  {'City Name': 'Labuhan',
#   'Temperature': 77.34,
#   'Humidity': 83,
#   'Cloudiness': 7,
#   'Wind': 5.55,
#   'Longitude': 112.2051,
#   'Latitude': -6.8844},
#  {'City Name': 'Bluff',
#   'Temperature': 48,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind': 5.01,
#   'Longitude': 168.3333,
#   'Latitude': -46.6},
#  {'City Name': 'Ushuaia',
#   'Temperature': 55.4,
#   'Humidity': 54,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': -68.3,
#   'Latitude': -54.8},
#  {'City Name': 'Saldanha',
#   'Temperature': 64.4,
#   'Humidity': 63,
#   'Cloudiness': 100,
#   'Wind': 8.05,
#   'Longitude': 17.9442,
#   'Latitude': -33.0117},
#  {'City Name': 'Mar del Plata',
#   'Temperature': 66.2,
#   'Humidity': 59,
#   'Cloudiness': 40,
#   'Wind': 14.97,
#   'Longitude': -57.5575,
#   'Latitude': -38.0023},
#  {'City Name': 'Mossamedes',
#   'Temperature': 79.23,
#   'Humidity': 75,
#   'Cloudiness': 0,
#   'Wind': 7.92,
#   'Longitude': 12.1522,
#   'Latitude': -15.1961},
#  {'City Name': 'Taoudenni',
#   'Temperature': 95.72,
#   'Humidity': 9,
#   'Cloudiness': 2,
#   'Wind': 10.65,
#   'Longitude': -3.9836,
#   'Latitude': 22.6783},
#  {'City Name': 'Soe',
#   'Temperature': 64,
#   'Humidity': 95,
#   'Cloudiness': 60,
#   'Wind': 3.58,
#   'Longitude': 124.284,
#   'Latitude': -9.8607},
#  {'City Name': 'Kapaa',
#   'Temperature': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind': 17.27,
#   'Longitude': -159.319,
#   'Latitude': 22.0752},
#  {'City Name': 'Hobart',
#   'Temperature': 48.99,
#   'Humidity': 81,
#   'Cloudiness': 40,
#   'Wind': 9.22,
#   'Longitude': 147.3294,
#   'Latitude': -42.8794},
#  {'City Name': 'Yar-Sale',
#   'Temperature': 24.75,
#   'Humidity': 96,
#   'Cloudiness': 56,
#   'Wind': 4.34,
#   'Longitude': 70.8333,
#   'Latitude': 66.8333},
#  {'City Name': 'Petatlán',
#   'Temperature': 86,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind': 8.25,
#   'Longitude': -101.2667,
#   'Latitude': 17.5167},
#  {'City Name': 'Mataura',
#   'Temperature': 48,
#   'Humidity': 88,
#   'Cloudiness': 86,
#   'Wind': 4,
#   'Longitude': 168.8643,
#   'Latitude': -46.1927},
#  {'City Name': 'Cape Town',
#   'Temperature': 63,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind': 11.5,
#   'Longitude': 18.4232,
#   'Latitude': -33.9258},
#  {'City Name': 'Mehamn',
#   'Temperature': 32.7,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind': 9.04,
#   'Longitude': 27.8492,
#   'Latitude': 71.0357},
#  {'City Name': 'Punta Arenas',
#   'Temperature': 51.8,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind': 9.22,
#   'Longitude': -70.9167,
#   'Latitude': -53.15},
#  {'City Name': 'Faanui',
#   'Temperature': 80.44,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind': 9.69,
#   'Longitude': -151.75,
#   'Latitude': -16.4833},
#  {'City Name': 'Saint-Philippe',
#   'Temperature': 77,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind': 27.63,
#   'Longitude': 55.7679,
#   'Latitude': -21.3585},
#  {'City Name': 'Yellowknife',
#   'Temperature': 19,
#   'Humidity': 57,
#   'Cloudiness': 75,
#   'Wind': 12.66,
#   'Longitude': -114.3525,
#   'Latitude': 62.456},
#  {'City Name': 'Hermanus',
#   'Temperature': 62.01,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind': 3,
#   'Longitude': 19.2345,
#   'Latitude': -34.4187},
#  {'City Name': 'Monrovia',
#   'Temperature': 86,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind': 6.91,
#   'Longitude': -10.7969,
#   'Latitude': 6.3005},
#  {'City Name': 'Tacna',
#   'Temperature': 71.6,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind': 11.5,
#   'Longitude': -70.2483,
#   'Latitude': -18.0056},
#  {'City Name': 'Nikolskoye',
#   'Temperature': 39.2,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind': 4.47,
#   'Longitude': 30.7861,
#   'Latitude': 59.7035},
#  {'City Name': 'Golspie',
#   'Temperature': 48.99,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind': 1.99,
#   'Longitude': -3.978,
#   'Latitude': 57.9727},
#  {'City Name': 'New Norfolk',
#   'Temperature': 48.99,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind': 2.48,
#   'Longitude': 147.0587,
#   'Latitude': -42.7826},
#  {'City Name': 'Rikitea',
#   'Temperature': 78.58,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind': 16.37,
#   'Longitude': -134.9692,
#   'Latitude': -23.1203},
#  {'City Name': 'San Patricio',
#   'Temperature': 96.8,
#   'Humidity': 11,
#   'Cloudiness': 1,
#   'Wind': 16.11,
#   'Longitude': -97.5169,
#   'Latitude': 28.017},
#  {'City Name': 'Panabá',
#   'Temperature': 94.17,
#   'Humidity': 34,
#   'Cloudiness': 100,
#   'Wind': 17.22,
#   'Longitude': -88.2667,
#   'Latitude': 21.2833},
#  {'City Name': 'Smidovich',
#   'Temperature': 35.01,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind': 17.83,
#   'Longitude': 133.8167,
#   'Latitude': 48.6},
#  {'City Name': 'Landau',
#   'Temperature': 57,
#   'Humidity': 35,
#   'Cloudiness': 66,
#   'Wind': 7.65,
#   'Longitude': 8.1133,
#   'Latitude': 49.2075},
#  {'City Name': 'Awjilah',
#   'Temperature': 67.55,
#   'Humidity': 59,
#   'Cloudiness': 0,
#   'Wind': 24.7,
#   'Longitude': 21.2869,
#   'Latitude': 29.1081},
#  {'City Name': 'Pisco',
#   'Temperature': 73.4,
#   'Humidity': 68,
#   'Cloudiness': 0,
#   'Wind': 20.71,
#   'Longitude': -76.2167,
#   'Latitude': -13.7},
#  {'City Name': 'Albany',
#   'Temperature': 70,
#   'Humidity': 17,
#   'Cloudiness': 87,
#   'Wind': 3,
#   'Longitude': -73.9662,
#   'Latitude': 42.6001},
#  {'City Name': 'Lavrentiya',
#   'Temperature': 28.24,
#   'Humidity': 88,
#   'Cloudiness': 93,
#   'Wind': 1.28,
#   'Longitude': -171,
#   'Latitude': 65.5833},
#  {'City Name': 'Zhovti Vody',
#   'Temperature': 39,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind': 4.47,
#   'Longitude': 33.5003,
#   'Latitude': 48.3473},
#  {'City Name': 'Fortuna',
#   'Temperature': 55,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind': 10.36,
#   'Longitude': -124.1573,
#   'Latitude': 40.5982},
#  {'City Name': 'Iqaluit',
#   'Temperature': 35.6,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind': 4.61,
#   'Longitude': -68.5145,
#   'Latitude': 63.7506},
#  {'City Name': 'Gualaquiza',
#   'Temperature': 75.24,
#   'Humidity': 74,
#   'Cloudiness': 64,
#   'Wind': 2.64,
#   'Longitude': -78.55,
#   'Latitude': -3.4},
#  {'City Name': 'Monchegorsk',
#   'Temperature': 33.01,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind': 7.85,
#   'Longitude': 32.8739,
#   'Latitude': 67.9397},
#  {'City Name': 'Tasiilaq',
#   'Temperature': 37.4,
#   'Humidity': 75,
#   'Cloudiness': 75,
#   'Wind': 1.14,
#   'Longitude': -37.6368,
#   'Latitude': 65.6145},
#  {'City Name': 'Anūpgarh',
#   'Temperature': 82.17,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind': 6.53,
#   'Longitude': 73.2086,
#   'Latitude': 29.1911},
#  {'City Name': 'Thompson',
#   'Temperature': 24.8,
#   'Humidity': 50,
#   'Cloudiness': 75,
#   'Wind': 2.3,
#   'Longitude': -97.8558,
#   'Latitude': 55.7435},
#  {'City Name': "Severo-Kuril'sk",
#   'Temperature': 34.84,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind': 4.54,
#   'Longitude': 156.125,
#   'Latitude': 50.6789},
#  {'City Name': 'Busselton',
#   'Temperature': 52,
#   'Humidity': 89,
#   'Cloudiness': 0,
#   'Wind': 1.95,
#   'Longitude': 115.3333,
#   'Latitude': -33.65},
#  {'City Name': 'Avarua',
#   'Temperature': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind': 13.8,
#   'Longitude': -159.775,
#   'Latitude': -21.2078},
#  {'City Name': 'Béboto',
#   'Temperature': 82.02,
#   'Humidity': 55,
#   'Cloudiness': 68,
#   'Wind': 9.06,
#   'Longitude': 16.939,
#   'Latitude': 8.2668},
#  {'City Name': 'Nicoya',
#   'Temperature': 91.4,
#   'Humidity': 43,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': -85.452,
#   'Latitude': 10.1483},
#  {'City Name': 'Meulaboh',
#   'Temperature': 75.88,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind': 2.82,
#   'Longitude': 96.1285,
#   'Latitude': 4.1363},
#  {'City Name': 'Khatanga',
#   'Temperature': 32.18,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind': 16.82,
#   'Longitude': 102.5,
#   'Latitude': 71.9667},
#  {'City Name': 'Provideniya',
#   'Temperature': 35.51,
#   'Humidity': 83,
#   'Cloudiness': 99,
#   'Wind': 0.92,
#   'Longitude': -173.3,
#   'Latitude': 64.3833},
#  {'City Name': 'Longyearbyen',
#   'Temperature': 26.6,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind': 3.44,
#   'Longitude': 15.6401,
#   'Latitude': 78.2186},
#  {'City Name': 'Dingle',
#   'Temperature': 76.06,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind': 1.12,
#   'Longitude': 122.6711,
#   'Latitude': 10.9995},
#  {'City Name': 'Atuona',
#   'Temperature': 80.74,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind': 20.49,
#   'Longitude': -139.0333,
#   'Latitude': -9.8},
#  {'City Name': 'Dikson',
#   'Temperature': 7.11,
#   'Humidity': 95,
#   'Cloudiness': 14,
#   'Wind': 12.24,
#   'Longitude': 80.5464,
#   'Latitude': 73.5069},
#  {'City Name': 'Tingi',
#   'Temperature': 62.56,
#   'Humidity': 95,
#   'Cloudiness': 39,
#   'Wind': 3.15,
#   'Longitude': 35.0333,
#   'Latitude': -11.3},
#  {'City Name': 'Ahipara',
#   'Temperature': 58.42,
#   'Humidity': 80,
#   'Cloudiness': 27,
#   'Wind': 8.41,
#   'Longitude': 173.1667,
#   'Latitude': -35.1667},
#  {'City Name': 'Qaanaaq',
#   'Temperature': 27.73,
#   'Humidity': 69,
#   'Cloudiness': 93,
#   'Wind': 6.49,
#   'Longitude': -69.3632,
#   'Latitude': 77.484},
#  {'City Name': 'Verkhnevilyuysk',
#   'Temperature': 31.08,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind': 5.55,
#   'Longitude': 120.3167,
#   'Latitude': 63.4453},
#  {'City Name': 'Castro',
#   'Temperature': 72.99,
#   'Humidity': 53,
#   'Cloudiness': 65,
#   'Wind': 5.08,
#   'Longitude': -50.0119,
#   'Latitude': -24.7911},
#  {'City Name': 'Talnakh',
#   'Temperature': 30.42,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind': 13.71,
#   'Longitude': 88.3972,
#   'Latitude': 69.4865},
#  {'City Name': 'Ajuchitlán',
#   'Temperature': 82.4,
#   'Humidity': 18,
#   'Cloudiness': 75,
#   'Wind': 17.27,
#   'Longitude': -100.0167,
#   'Latitude': 20.7167},
#  {'City Name': 'Tres Arroyos',
#   'Temperature': 62.28,
#   'Humidity': 51,
#   'Cloudiness': 6,
#   'Wind': 16.26,
#   'Longitude': -60.2798,
#   'Latitude': -38.3739},
#  {'City Name': 'Vestmannaeyjar',
#   'Temperature': 44.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind': 19.57,
#   'Longitude': -20.2734,
#   'Latitude': 63.4427},
#  {'City Name': 'Ugoofaaru',
#   'Temperature': 83.68,
#   'Humidity': 72,
#   'Cloudiness': 50,
#   'Wind': 5.44,
#   'Longitude': 73,
#   'Latitude': 5.6667},
#  {'City Name': 'Mormugao',
#   'Temperature': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind': 5.75,
#   'Longitude': 73.8,
#   'Latitude': 15.4},
#  {'City Name': 'Jasper',
#   'Temperature': 64.4,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind': 14.97,
#   'Longitude': -94.3502,
#   'Latitude': 37.2001},
#  {'City Name': 'Grand Gaube',
#   'Temperature': 79,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind': 10,
#   'Longitude': 57.6608,
#   'Latitude': -20.0064},
#  {'City Name': 'Bengkulu',
#   'Temperature': 75.4,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind': 4.03,
#   'Longitude': 102.2655,
#   'Latitude': -3.8004},
#  {'City Name': 'Hithadhoo',
#   'Temperature': 83.25,
#   'Humidity': 69,
#   'Cloudiness': 13,
#   'Wind': 7.29,
#   'Longitude': 73.0833,
#   'Latitude': -0.6},
#  {'City Name': 'Illapel',
#   'Temperature': 75.47,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind': 6.8,
#   'Longitude': -71.1653,
#   'Latitude': -31.6308},
#  {'City Name': 'Quatre Cocos',
#   'Temperature': 79,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind': 17.27,
#   'Longitude': 57.7625,
#   'Latitude': -20.2078},
#  {'City Name': 'Los Llanos de Aridane',
#   'Temperature': 71.6,
#   'Humidity': 56,
#   'Cloudiness': 20,
#   'Wind': 8.05,
#   'Longitude': -17.9182,
#   'Latitude': 28.6585},
#  {'City Name': 'Kaitangata',
#   'Temperature': 45,
#   'Humidity': 88,
#   'Cloudiness': 23,
#   'Wind': 4,
#   'Longitude': 169.8464,
#   'Latitude': -46.2817},
#  {'City Name': 'Laguna',
#   'Temperature': 66.99,
#   'Humidity': 37,
#   'Cloudiness': 20,
#   'Wind': 10.36,
#   'Longitude': -121.4238,
#   'Latitude': 38.421},
#  {'City Name': 'Āsosa',
#   'Temperature': 66.02,
#   'Humidity': 75,
#   'Cloudiness': 89,
#   'Wind': 6.17,
#   'Longitude': 34.5333,
#   'Latitude': 10.0667},
#  {'City Name': 'Hilo',
#   'Temperature': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind': 6.91,
#   'Longitude': -155.09,
#   'Latitude': 19.7297},
#  {'City Name': 'Kawalu',
#   'Temperature': 70.47,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind': 1.36,
#   'Longitude': 108.2082,
#   'Latitude': -7.3817},
#  {'City Name': 'Jamestown',
#   'Temperature': 62.01,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind': 13.8,
#   'Longitude': -79.2353,
#   'Latitude': 42.097},
#  {'City Name': 'Bredasdorp',
#   'Temperature': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 96,
#   'Wind': 5.75,
#   'Longitude': 20.0403,
#   'Latitude': -34.5322},
#  {'City Name': 'Lake Charles',
#   'Temperature': 89.6,
#   'Humidity': 48,
#   'Cloudiness': 40,
#   'Wind': 11.5,
#   'Longitude': -93.2044,
#   'Latitude': 30.2131},
#  {'City Name': 'Chui',
#   'Temperature': 71.38,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind': 6.38,
#   'Longitude': -53.4616,
#   'Latitude': -33.6971},
#  {'City Name': 'Tuktoyaktuk',
#   'Temperature': 23,
#   'Humidity': 80,
#   'Cloudiness': 40,
#   'Wind': 6.91,
#   'Longitude': -133.0374,
#   'Latitude': 69.4541},
#  {'City Name': 'Esso',
#   'Temperature': 31.86,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind': 2.21,
#   'Longitude': 158.7,
#   'Latitude': 55.9333},
#  {'City Name': 'Puerto Ayora',
#   'Temperature': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind': 9.22,
#   'Longitude': -90.3518,
#   'Latitude': -0.7393},
#  {'City Name': 'Bathsheba',
#   'Temperature': 84.2,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind': 19.57,
#   'Longitude': -59.5167,
#   'Latitude': 13.2167},
#  {'City Name': 'Rurrenabaque',
#   'Temperature': 84.2,
#   'Humidity': 84,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': -67.5278,
#   'Latitude': -14.4413},
#  {'City Name': 'Kamenka',
#   'Temperature': 42.01,
#   'Humidity': 81,
#   'Cloudiness': 7,
#   'Wind': 13.4,
#   'Longitude': 42.7678,
#   'Latitude': 51.3223},
#  {'City Name': 'Contamana',
#   'Temperature': 90.79,
#   'Humidity': 49,
#   'Cloudiness': 89,
#   'Wind': 4.99,
#   'Longitude': -75.0167,
#   'Latitude': -7.3333},
#  {'City Name': 'Sorong',
#   'Temperature': 78.28,
#   'Humidity': 86,
#   'Cloudiness': 63,
#   'Wind': 6.8,
#   'Longitude': 131.25,
#   'Latitude': -0.8833},
#  {'City Name': 'Souillac',
#   'Temperature': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind': 17.27,
#   'Longitude': 57.5167,
#   'Latitude': -20.5167},
#  {'City Name': 'Harper',
#   'Temperature': 82.33,
#   'Humidity': 78,
#   'Cloudiness': 92,
#   'Wind': 10.07,
#   'Longitude': -7.7169,
#   'Latitude': 4.375},
#  {'City Name': 'Haines Junction',
#   'Temperature': 42.8,
#   'Humidity': 39,
#   'Cloudiness': 15,
#   'Wind': 2.3,
#   'Longitude': -137.5108,
#   'Latitude': 60.7522},
#  {'City Name': 'Cabo San Lucas',
#   'Temperature': 78.8,
#   'Humidity': 43,
#   'Cloudiness': 1,
#   'Wind': 5.75,
#   'Longitude': -109.9124,
#   'Latitude': 22.8909},
#  {'City Name': 'Butaritari',
#   'Temperature': 82.47,
#   'Humidity': 76,
#   'Cloudiness': 52,
#   'Wind': 12.12,
#   'Longitude': 172.7902,
#   'Latitude': 3.0707},
#  {'City Name': 'Kologriv',
#   'Temperature': 45.34,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind': 11.1,
#   'Longitude': 44.3178,
#   'Latitude': 58.8275},
#  {'City Name': 'Killybegs',
#   'Temperature': 62.6,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind': 11.5,
#   'Longitude': -8.45,
#   'Latitude': 54.6333},
#  {'City Name': 'Pimentel',
#   'Temperature': 77,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind': 23.02,
#   'Longitude': -79.9342,
#   'Latitude': -6.8367},
#  {'City Name': 'Samarai',
#   'Temperature': 82.4,
#   'Humidity': 78,
#   'Cloudiness': 88,
#   'Wind': 14.32,
#   'Longitude': 150.6667,
#   'Latitude': -10.6167},
#  {'City Name': 'Barrow',
#   'Temperature': 21.2,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind': 3.44,
#   'Longitude': -156.7887,
#   'Latitude': 71.2906},
#  {'City Name': 'Ayní',
#   'Temperature': 49.77,
#   'Humidity': 62,
#   'Cloudiness': 46,
#   'Wind': 5.28,
#   'Longitude': 68.5377,
#   'Latitude': 39.3941},
#  {'City Name': 'San Quintín',
#   'Temperature': 64.09,
#   'Humidity': 66,
#   'Cloudiness': 15,
#   'Wind': 16.82,
#   'Longitude': -115.95,
#   'Latitude': 30.4833},
#  {'City Name': 'Vaini',
#   'Temperature': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 40,
#   'Wind': 1.14,
#   'Longitude': -175.2,
#   'Latitude': -21.2},
#  {'City Name': 'Passos',
#   'Temperature': 84.15,
#   'Humidity': 20,
#   'Cloudiness': 0,
#   'Wind': 2.33,
#   'Longitude': -46.6097,
#   'Latitude': -20.7189},
#  {'City Name': 'Ambanja',
#   'Temperature': 75.31,
#   'Humidity': 91,
#   'Cloudiness': 44,
#   'Wind': 3.2,
#   'Longitude': 48.45,
#   'Latitude': -13.6833},
#  {'City Name': 'Bud',
#   'Temperature': 52,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind': 6.85,
#   'Longitude': -86.1758,
#   'Latitude': 39.447},
#  {'City Name': 'Gijang',
#   'Temperature': 59,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind': 1.14,
#   'Longitude': 129.2139,
#   'Latitude': 35.2442},
#  {'City Name': 'Coquimbo',
#   'Temperature': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind': 12.66,
#   'Longitude': -71.3436,
#   'Latitude': -29.9533},
#  {'City Name': 'Zihuatanejo',
#   'Temperature': 86,
#   'Humidity': 66,
#   'Cloudiness': 1,
#   'Wind': 8.52,
#   'Longitude': -101.55,
#   'Latitude': 17.6333},
#  {'City Name': 'Upernavik',
#   'Temperature': 34.2,
#   'Humidity': 85,
#   'Cloudiness': 11,
#   'Wind': 5.91,
#   'Longitude': -56.1549,
#   'Latitude': 72.7868},
#  {'City Name': 'Kurumkan',
#   'Temperature': 41.92,
#   'Humidity': 43,
#   'Cloudiness': 100,
#   'Wind': 4.32,
#   'Longitude': 110.3,
#   'Latitude': 54.3},
#  {'City Name': 'Fort-Shevchenko',
#   'Temperature': 58.03,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind': 3.06,
#   'Longitude': 50.263,
#   'Latitude': 44.5086},
#  {'City Name': 'Salamiyah',
#   'Temperature': 75.7,
#   'Humidity': 33,
#   'Cloudiness': 100,
#   'Wind': 15.26,
#   'Longitude': 37.0532,
#   'Latitude': 35.0113},
#  {'City Name': 'Ust-Maya',
#   'Temperature': 16.25,
#   'Humidity': 97,
#   'Cloudiness': 80,
#   'Wind': 3.53,
#   'Longitude': 134.5333,
#   'Latitude': 60.4167},
#  {'City Name': 'Carnarvon',
#   'Temperature': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind': 9.22,
#   'Longitude': 113.6333,
#   'Latitude': -24.8667},
#  {'City Name': 'Hamilton',
#   'Temperature': 53.01,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind': 3.44,
#   'Longitude': -84.5333,
#   'Latitude': 39.1834},
#  {'City Name': 'Jalu',
#   'Temperature': 68.9,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind': 25.21,
#   'Longitude': 21.5482,
#   'Latitude': 29.0331},
#  {'City Name': 'Zhigansk',
#   'Temperature': 33.03,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind': 9.71,
#   'Longitude': 123.3711,
#   'Latitude': 66.7697},
#  {'City Name': 'Alofi',
#   'Temperature': 71.6,
#   'Humidity': 100,
#   'Cloudiness': 87,
#   'Wind': 1.14,
#   'Longitude': -169.9187,
#   'Latitude': -19.0595},
#  {'City Name': 'Altay',
#   'Temperature': 24.62,
#   'Humidity': 57,
#   'Cloudiness': 51,
#   'Wind': 6.35,
#   'Longitude': 88.1167,
#   'Latitude': 47.8667},
#  {'City Name': 'Bethel',
#   'Temperature': 70,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind': 8.05,
#   'Longitude': -73.414,
#   'Latitude': 41.3712},
#  {'City Name': 'Zuwārah',
#   'Temperature': 61.57,
#   'Humidity': 75,
#   'Cloudiness': 4,
#   'Wind': 9.1,
#   'Longitude': 12.082,
#   'Latitude': 32.9312},
#  {'City Name': 'Ribeira Grande',
#   'Temperature': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind': 20.71,
#   'Longitude': -28.7,
#   'Latitude': 38.5167},
#  {'City Name': 'Saint George',
#   'Temperature': 80.01,
#   'Humidity': 14,
#   'Cloudiness': 1,
#   'Wind': 20.71,
#   'Longitude': -113.5841,
#   'Latitude': 37.1041},
#  {'City Name': 'Wilmington',
#   'Temperature': 68,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind': 8.05,
#   'Longitude': -77.9447,
#   'Latitude': 34.2257},
#  {'City Name': 'El Paraíso',
#   'Temperature': 92.16,
#   'Humidity': 20,
#   'Cloudiness': 60,
#   'Wind': 2.89,
#   'Longitude': -86.55,
#   'Latitude': 13.8667},
#  {'City Name': 'Kalat',
#   'Temperature': 63.1,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind': 5.3,
#   'Longitude': 66.5916,
#   'Latitude': 29.0225},
#  {'City Name': 'Inhambane',
#   'Temperature': 71.96,
#   'Humidity': 79,
#   'Cloudiness': 0,
#   'Wind': 8.16,
#   'Longitude': 35.3833,
#   'Latitude': -23.865},
#  {'City Name': 'Mananjary',
#   'Temperature': 71.44,
#   'Humidity': 90,
#   'Cloudiness': 28,
#   'Wind': 3.85,
#   'Longitude': 48.3333,
#   'Latitude': -21.2167},
#  {'City Name': 'Flagstaff',
#   'Temperature': 62.01,
#   'Humidity': 21,
#   'Cloudiness': 1,
#   'Wind': 27.63,
#   'Longitude': -111.6513,
#   'Latitude': 35.1981},
#  {'City Name': 'Sitka',
#   'Temperature': 57.2,
#   'Humidity': 30,
#   'Cloudiness': 1,
#   'Wind': 2.44,
#   'Longitude': -135.33,
#   'Latitude': 57.0531},
#  {'City Name': 'Acarí',
#   'Temperature': 78.78,
#   'Humidity': 55,
#   'Cloudiness': 3,
#   'Wind': 11.12,
#   'Longitude': -74.6158,
#   'Latitude': -15.4311},
#  {'City Name': 'Bundaberg',
#   'Temperature': 62.01,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind': 9.22,
#   'Longitude': 152.35,
#   'Latitude': -24.85},
#  {'City Name': 'Vanimo',
#   'Temperature': 76.82,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind': 4.41,
#   'Longitude': 141.3028,
#   'Latitude': -2.6741},
#  {'City Name': 'Sungurlu',
#   'Temperature': 56.75,
#   'Humidity': 60,
#   'Cloudiness': 100,
#   'Wind': 6.62,
#   'Longitude': 34.3739,
#   'Latitude': 40.1675},
#  {'City Name': 'Gao',
#   'Temperature': 92.68,
#   'Humidity': 5,
#   'Cloudiness': 1,
#   'Wind': 8.55,
#   'Longitude': 1.637,
#   'Latitude': 16.6362},
#  {'City Name': 'Narsaq',
#   'Temperature': 55.4,
#   'Humidity': 33,
#   'Cloudiness': 75,
#   'Wind': 25.32,
#   'Longitude': -46.05,
#   'Latitude': 60.9167},
#  {'City Name': 'Cayenne',
#   'Temperature': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind': 6.91,
#   'Longitude': -52.3333,
#   'Latitude': 4.9333},
#  {'City Name': 'Mahébourg',
#   'Temperature': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind': 17.27,
#   'Longitude': 57.7,
#   'Latitude': -20.4081},
#  {'City Name': 'Cidreira',
#   'Temperature': 73.62,
#   'Humidity': 72,
#   'Cloudiness': 8,
#   'Wind': 12.46,
#   'Longitude': -50.2056,
#   'Latitude': -30.1811},
#  {'City Name': 'Mahajanga',
#   'Temperature': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind': 2.3,
#   'Longitude': 46.3167,
#   'Latitude': -15.7167},
#  {'City Name': 'Esperance',
#   'Temperature': 59,
#   'Humidity': 72,
#   'Cloudiness': 44,
#   'Wind': 14.97,
#   'Longitude': 121.9,
#   'Latitude': -33.8667},
#  {'City Name': 'Naze',
#   'Temperature': 64.09,
#   'Humidity': 70,
#   'Cloudiness': 99,
#   'Wind': 19.1,
#   'Longitude': 129.4833,
#   'Latitude': 28.3667},
#  {'City Name': 'Kenai',
#   'Temperature': 46.4,
#   'Humidity': 65,
#   'Cloudiness': 1,
#   'Wind': 5.75,
#   'Longitude': -151.2583,
#   'Latitude': 60.5544},
#  {'City Name': 'Puerto Carreño',
#   'Temperature': 94.44,
#   'Humidity': 42,
#   'Cloudiness': 88,
#   'Wind': 8.32,
#   'Longitude': -67.4859,
#   'Latitude': 6.189},
#  {'City Name': 'Port Elizabeth',
#   'Temperature': 59,
#   'Humidity': 94,
#   'Cloudiness': 0,
#   'Wind': 6.91,
#   'Longitude': 25.5701,
#   'Latitude': -33.918},
#  {'City Name': 'Polokwane',
#   'Temperature': 64.4,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind': 2.3,
#   'Longitude': 29.4688,
#   'Latitude': -23.9045},
#  {'City Name': 'Rangāpāra',
#   'Temperature': 75.09,
#   'Humidity': 38,
#   'Cloudiness': 75,
#   'Wind': 4.09,
#   'Longitude': 92.65,
#   'Latitude': 26.8167},
#  {'City Name': 'Yavaros',
#   'Temperature': 91.99,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind': 9.37,
#   'Longitude': -109.5167,
#   'Latitude': 26.7},
#  {'City Name': 'Shimoda',
#   'Temperature': 52,
#   'Humidity': 82,
#   'Cloudiness': 16,
#   'Wind': 3,
#   'Longitude': 138.95,
#   'Latitude': 34.6667},
#  {'City Name': 'Outjo',
#   'Temperature': 70.86,
#   'Humidity': 29,
#   'Cloudiness': 70,
#   'Wind': 3.89,
#   'Longitude': 16.15,
#   'Latitude': -20.1167},
#  {'City Name': 'Kinablangan',
#   'Temperature': 78.48,
#   'Humidity': 81,
#   'Cloudiness': 61,
#   'Wind': 5.06,
#   'Longitude': 126.5503,
#   'Latitude': 7.6947},
#  {'City Name': 'Manitouwadge',
#   'Temperature': 32,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind': 12.66,
#   'Longitude': -85.8403,
#   'Latitude': 49.1215},
#  {'City Name': 'Bengbu',
#   'Temperature': 53.96,
#   'Humidity': 89,
#   'Cloudiness': 99,
#   'Wind': 8.05,
#   'Longitude': 117.3608,
#   'Latitude': 32.9408},
#  {'City Name': 'Mount Isa',
#   'Temperature': 68,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind': 5.75,
#   'Longitude': 139.5,
#   'Latitude': -20.7333},
#  {'City Name': 'Saint Paul Harbor',
#   'Temperature': 44.6,
#   'Humidity': 76,
#   'Cloudiness': 90,
#   'Wind': 4.61,
#   'Longitude': -152.4072,
#   'Latitude': 57.79},
#  {'City Name': 'Maragogi',
#   'Temperature': 81.43,
#   'Humidity': 76,
#   'Cloudiness': 40,
#   'Wind': 8.16,
#   'Longitude': -35.2225,
#   'Latitude': -9.0122},
#  {'City Name': 'Leningradskiy',
#   'Temperature': 22.5,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind': 5.12,
#   'Longitude': 178.4167,
#   'Latitude': 69.3833},
#  {'City Name': 'Nuevo Progreso',
#   'Temperature': 93,
#   'Humidity': 52,
#   'Cloudiness': 56,
#   'Wind': 17,
#   'Longitude': -97.95,
#   'Latitude': 23.1667},
#  {'City Name': 'Lázaro Cárdenas',
#   'Temperature': 85.28,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind': 10.92,
#   'Longitude': -102.2,
#   'Latitude': 17.9583},
#  {'City Name': 'Rundu',
#   'Temperature': 65.41,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind': 5.21,
#   'Longitude': 19.7667,
#   'Latitude': -17.9333},
#  {'City Name': 'East London',
#   'Temperature': 64.4,
#   'Humidity': 88,
#   'Cloudiness': 0,
#   'Wind': 5.75,
#   'Longitude': 27.9116,
#   'Latitude': -33.0153},
#  {'City Name': 'Norman Wells',
#   'Temperature': 33.8,
#   'Humidity': 47,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': -126.8329,
#   'Latitude': 65.282},
#  {'City Name': 'Georgiyevskoye',
#   'Temperature': 44.4,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind': 11.16,
#   'Longitude': 45.024,
#   'Latitude': 58.731},
#  {'City Name': 'Wahiawā',
#   'Temperature': 78.01,
#   'Humidity': 68,
#   'Cloudiness': 40,
#   'Wind': 6.91,
#   'Longitude': -158.0236,
#   'Latitude': 21.5028},
#  {'City Name': 'Niksar',
#   'Temperature': 53.19,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind': 3.62,
#   'Longitude': 36.9517,
#   'Latitude': 40.5917},
#  {'City Name': 'George Town',
#   'Temperature': 82,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind': 3.44,
#   'Longitude': 100.3354,
#   'Latitude': 5.4112},
#  {'City Name': 'Avera',
#   'Temperature': 64.99,
#   'Humidity': 90,
#   'Cloudiness': 90,
#   'Wind': 8.05,
#   'Longitude': -82.5271,
#   'Latitude': 33.194},
#  {'City Name': 'Kruisfontein',
#   'Temperature': 60.01,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind': 1.01,
#   'Longitude': 24.7314,
#   'Latitude': -34.0033},
#  {'City Name': 'Beloha',
#   'Temperature': 75.27,
#   'Humidity': 63,
#   'Cloudiness': 13,
#   'Wind': 14.05,
#   'Longitude': 45.05,
#   'Latitude': -25.1667},
#  {'City Name': 'Lebu',
#   'Temperature': 57.58,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind': 17.43,
#   'Longitude': -73.65,
#   'Latitude': -37.6167},
#  {'City Name': 'Namatanai',
#   'Temperature': 78.49,
#   'Humidity': 81,
#   'Cloudiness': 36,
#   'Wind': 4.07,
#   'Longitude': 152.4333,
#   'Latitude': -3.6667},
#  {'City Name': 'Chumikan',
#   'Temperature': 22.87,
#   'Humidity': 76,
#   'Cloudiness': 20,
#   'Wind': 9.55,
#   'Longitude': 135.315,
#   'Latitude': 54.7183},
#  {'City Name': 'Pierre',
#   'Temperature': 46.4,
#   'Humidity': 36,
#   'Cloudiness': 20,
#   'Wind': 6.02,
#   'Longitude': -100.351,
#   'Latitude': 44.3683},
#  {'City Name': 'Makakilo City',
#   'Temperature': 80.6,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind': 9.22,
#   'Longitude': -158.0858,
#   'Latitude': 21.3469},
#  {'City Name': 'Azare',
#   'Temperature': 91.53,
#   'Humidity': 21,
#   'Cloudiness': 100,
#   'Wind': 2.91,
#   'Longitude': 10.1948,
#   'Latitude': 11.6765},
#  {'City Name': 'Vágur',
#   'Temperature': 46.8,
#   'Humidity': 78,
#   'Cloudiness': 100,
#   'Wind': 3.91,
#   'Longitude': -6.8119,
#   'Latitude': 61.4732},
#  {'City Name': 'Gonder',
#   'Temperature': 68.63,
#   'Humidity': 40,
#   'Cloudiness': 87,
#   'Wind': 2.71,
#   'Longitude': 37.4667,
#   'Latitude': 12.6},
#  {'City Name': 'Rawson',
#   'Temperature': 60.51,
#   'Humidity': 45,
#   'Cloudiness': 14,
#   'Wind': 0.74,
#   'Longitude': -65.1023,
#   'Latitude': -43.3002},
#  {'City Name': 'Havøysund',
#   'Temperature': 30.2,
#   'Humidity': 86,
#   'Cloudiness': 90,
#   'Wind': 9.22,
#   'Longitude': 24.6622,
#   'Latitude': 70.9963},
#  {'City Name': 'Praia da Vitória',
#   'Temperature': 62.6,
#   'Humidity': 77,
#   'Cloudiness': 75,
#   'Wind': 28.41,
#   'Longitude': -27.0667,
#   'Latitude': 38.7333},
#  {'City Name': 'Karratha',
#   'Temperature': 78.82,
#   'Humidity': 35,
#   'Cloudiness': 0,
#   'Wind': 8.25,
#   'Longitude': 116.8463,
#   'Latitude': -20.7377},
#  {'City Name': 'Tambun',
#   'Temperature': 81,
#   'Humidity': 78,
#   'Cloudiness': 40,
#   'Wind': 3.44,
#   'Longitude': 107.0712,
#   'Latitude': -6.2641},
#  {'City Name': 'Maniitsoq',
#   'Temperature': 39.27,
#   'Humidity': 72,
#   'Cloudiness': 3,
#   'Wind': 2.71,
#   'Longitude': -52.9,
#   'Latitude': 65.4167},
#  {'City Name': 'Korla',
#   'Temperature': 50.16,
#   'Humidity': 42,
#   'Cloudiness': 0,
#   'Wind': 12.08,
#   'Longitude': 86.1469,
#   'Latitude': 41.7597},
#  {'City Name': 'Isangel',
#   'Temperature': 77.05,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind': 10.13,
#   'Longitude': 169.2667,
#   'Latitude': -19.55},
#  {'City Name': 'Linqiong',
#   'Temperature': 66.2,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind': 2.24,
#   'Longitude': 103.4609,
#   'Latitude': 30.4159},
#  {'City Name': 'Morden',
#   'Temperature': 42.8,
#   'Humidity': 19,
#   'Cloudiness': 100,
#   'Wind': 3.44,
#   'Longitude': -98.1014,
#   'Latitude': 49.1919},
#  {'City Name': 'Kodinsk',
#   'Temperature': 33.22,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind': 2.04,
#   'Longitude': 99.1844,
#   'Latitude': 58.6881},
#  {'City Name': 'Graaff-Reinet',
#   'Temperature': 63,
#   'Humidity': 50,
#   'Cloudiness': 33,
#   'Wind': 1.99,
#   'Longitude': 24.5308,
#   'Latitude': -32.2522},
#  {'City Name': 'Kannapolis',
#   'Temperature': 57,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind': 12.37,
#   'Longitude': -80.6217,
#   'Latitude': 35.4874},
#  {'City Name': 'Kulhudhuffushi',
#   'Temperature': 83.5,
#   'Humidity': 72,
#   'Cloudiness': 16,
#   'Wind': 3.44,
#   'Longitude': 73.07,
#   'Latitude': 6.6221},
#  {'City Name': 'Port-Gentil',
#   'Temperature': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': 8.7815,
#   'Latitude': -0.7193},
#  {'City Name': 'Roald',
#   'Temperature': 37.4,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind': 3.44,
#   'Longitude': 6.1333,
#   'Latitude': 62.5833},
#  {'City Name': 'Broken Hill',
#   'Temperature': 51.8,
#   'Humidity': 66,
#   'Cloudiness': 0,
#   'Wind': 8.41,
#   'Longitude': 141.4333,
#   'Latitude': -31.95},
#  {'City Name': 'Srednekolymsk',
#   'Temperature': 11.3,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind': 8.63,
#   'Longitude': 153.6833,
#   'Latitude': 67.45},
#  {'City Name': 'Ulaanbaatar',
#   'Temperature': 50,
#   'Humidity': 22,
#   'Cloudiness': 75,
#   'Wind': 29.08,
#   'Longitude': 106.8832,
#   'Latitude': 47.9077},
#  {'City Name': 'Geraldton',
#   'Temperature': 59,
#   'Humidity': 94,
#   'Cloudiness': 91,
#   'Wind': 1.14,
#   'Longitude': 114.6,
#   'Latitude': -28.7667},
#  {'City Name': 'Qaqortoq',
#   'Temperature': 55.4,
#   'Humidity': 33,
#   'Cloudiness': 75,
#   'Wind': 25.32,
#   'Longitude': -46.0333,
#   'Latitude': 60.7167},
#  {'City Name': 'Terra Santa',
#   'Temperature': 85.01,
#   'Humidity': 77,
#   'Cloudiness': 77,
#   'Wind': 3.09,
#   'Longitude': -56.4869,
#   'Latitude': -2.1042},
#  {'City Name': 'Constitución',
#   'Temperature': 65.1,
#   'Humidity': 57,
#   'Cloudiness': 6,
#   'Wind': 16.26,
#   'Longitude': -72.4167,
#   'Latitude': -35.3333},
#  {'City Name': 'Peniche',
#   'Temperature': 66,
#   'Humidity': 69,
#   'Cloudiness': 100,
#   'Wind': 8.01,
#   'Longitude': -9.3811,
#   'Latitude': 39.3558},
#  {'City Name': 'Sinnamary',
#   'Temperature': 78.3,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind': 12.33,
#   'Longitude': -52.95,
#   'Latitude': 5.3833},
#  {'City Name': 'Te Anau',
#   'Temperature': 47.26,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind': 6.6,
#   'Longitude': 167.7167,
#   'Latitude': -45.4167},
#  {'City Name': 'Port Macquarie',
#   'Temperature': 53.01,
#   'Humidity': 90,
#   'Cloudiness': 0,
#   'Wind': 1.99,
#   'Longitude': 152.9167,
#   'Latitude': -31.4333},
#  {'City Name': 'Nhulunbuy',
#   'Temperature': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 98,
#   'Wind': 3.44,
#   'Longitude': 136.7667,
#   'Latitude': -12.2333},
#  {'City Name': 'Pochutla',
#   'Temperature': 91,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind': 17.27,
#   'Longitude': -96.4661,
#   'Latitude': 15.7432},
#  {'City Name': 'Mackay',
#   'Temperature': 68,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind': 4.61,
#   'Longitude': 149.2,
#   'Latitude': -21.15},
#  {'City Name': 'Hasaki',
#   'Temperature': 50,
#   'Humidity': 93,
#   'Cloudiness': 20,
#   'Wind': 4.61,
#   'Longitude': 140.8333,
#   'Latitude': 35.7333},
#  {'City Name': 'Mandapam',
#   'Temperature': 85.33,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind': 11.79,
#   'Longitude': 79.1167,
#   'Latitude': 9.2833},
#  {'City Name': 'Jhālu',
#   'Temperature': 74.86,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind': 6.98,
#   'Longitude': 78.25,
#   'Latitude': 29.35},
#  {'City Name': 'Saskylakh',
#   'Temperature': 31.57,
#   'Humidity': 92,
#   'Cloudiness': 96,
#   'Wind': 12.03,
#   'Longitude': 114.0833,
#   'Latitude': 71.9167},
#  {'City Name': 'Waterboro',
#   'Temperature': 73.4,
#   'Humidity': 18,
#   'Cloudiness': 75,
#   'Wind': 11.5,
#   'Longitude': -70.7151,
#   'Latitude': 43.5356},
#  {'City Name': 'Sarany',
#   'Temperature': 36.12,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind': 9.48,
#   'Longitude': 58.8833,
#   'Latitude': 58.5},
#  {'City Name': 'Boguchany',
#   'Temperature': 33.15,
#   'Humidity': 99,
#   'Cloudiness': 100,
#   'Wind': 2.57,
#   'Longitude': 97.4531,
#   'Latitude': 58.3814},
#  {'City Name': 'Yumen',
#   'Temperature': 49.41,
#   'Humidity': 36,
#   'Cloudiness': 84,
#   'Wind': 7.56,
#   'Longitude': 97.2,
#   'Latitude': 40.2833},
#  {'City Name': 'Airai',
#   'Temperature': 57.27,
#   'Humidity': 92,
#   'Cloudiness': 51,
#   'Wind': 2.75,
#   'Longitude': 125.4092,
#   'Latitude': -8.9266},
#  {'City Name': 'Homer',
#   'Temperature': 48,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind': 5.75,
#   'Longitude': -151.5483,
#   'Latitude': 59.6425},
#  {'City Name': 'Vung Tau',
#   'Temperature': 82.78,
#   'Humidity': 75,
#   'Cloudiness': 97,
#   'Wind': 7.52,
#   'Longitude': 107.0843,
#   'Latitude': 10.346},
#  {'City Name': 'Sakakah',
#   'Temperature': 86,
#   'Humidity': 10,
#   'Cloudiness': 0,
#   'Wind': 10.36,
#   'Longitude': 40.2064,
#   'Latitude': 29.9697},
#  {'City Name': 'Oranjemund',
#   'Temperature': 59.47,
#   'Humidity': 90,
#   'Cloudiness': 12,
#   'Wind': 2.55,
#   'Longitude': 16.4333,
#   'Latitude': -28.55},
#  {'City Name': 'Touros',
#   'Temperature': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind': 11.5,
#   'Longitude': -35.4608,
#   'Latitude': -5.1989},
#  {'City Name': 'Ponta do Sol',
#   'Temperature': 66.2,
#   'Humidity': 59,
#   'Cloudiness': 20,
#   'Wind': 4.61,
#   'Longitude': -17.1,
#   'Latitude': 32.6667},
#  {'City Name': 'Changde',
#   'Temperature': 56.1,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind': 14.36,
#   'Longitude': 111.6783,
#   'Latitude': 29.0464},
#  {'City Name': 'Honiara',
#   'Temperature': 77.97,
#   'Humidity': 84,
#   'Cloudiness': 100,
#   'Wind': 2.51,
#   'Longitude': 159.95,
#   'Latitude': -9.4333},
#  {'City Name': 'Ilulissat',
#   'Temperature': 41,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind': 6.91,
#   'Longitude': -51.1,
#   'Latitude': 69.2167},
#  {'City Name': 'San Juan',
#   'Temperature': 73.8,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind': 8.41,
#   'Longitude': -68.5364,
#   'Latitude': -31.5375},
#  {'City Name': 'Luancheng',
#   'Temperature': 57.2,
#   'Humidity': 77,
#   'Cloudiness': 0,
#   'Wind': 2.24,
#   'Longitude': 114.6517,
#   'Latitude': 37.8792},
#  {'City Name': 'Lagoa',
#   'Temperature': 58.86,
#   'Humidity': 83,
#   'Cloudiness': 35,
#   'Wind': 26.91,
#   'Longitude': -27.9833,
#   'Latitude': 39.05},
#  {'City Name': 'Ambon City',
#   'Temperature': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind': 5.75,
#   'Longitude': 128.1814,
#   'Latitude': -3.6954},
#  {'City Name': 'Pevek',
#   'Temperature': 19.22,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind': 2.77,
#   'Longitude': 170.3133,
#   'Latitude': 69.7008},
#  {'City Name': 'Ipixuna',
#   'Temperature': 77,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': -48.8043,
#   'Latitude': -1.7625},
#  {'City Name': 'Tremedal',
#   'Temperature': 85.91,
#   'Humidity': 42,
#   'Cloudiness': 40,
#   'Wind': 4.21,
#   'Longitude': -41.4108,
#   'Latitude': -14.9758},
#  {'City Name': 'Batticaloa',
#   'Temperature': 80.96,
#   'Humidity': 75,
#   'Cloudiness': 15,
#   'Wind': 3.65,
#   'Longitude': 81.6924,
#   'Latitude': 7.7102},
#  {'City Name': 'Ancud',
#   'Temperature': 62.01,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind': 11.5,
#   'Longitude': -73.8203,
#   'Latitude': -41.8697},
#  {'City Name': 'Magadan',
#   'Temperature': 15.1,
#   'Humidity': 69,
#   'Cloudiness': 96,
#   'Wind': 11.92,
#   'Longitude': 150.8,
#   'Latitude': 59.5667},
#  {'City Name': 'Vardø',
#   'Temperature': 33.73,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind': 22.75,
#   'Longitude': 31.1107,
#   'Latitude': 70.3705},
#  {'City Name': 'Togul',
#   'Temperature': 30.09,
#   'Humidity': 92,
#   'Cloudiness': 99,
#   'Wind': 3.24,
#   'Longitude': 85.9128,
#   'Latitude': 53.465},
#  {'City Name': 'Zhangye',
#   'Temperature': 50.34,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind': 3.89,
#   'Longitude': 100.4517,
#   'Latitude': 38.9342},
#  {'City Name': 'Ozinki',
#   'Temperature': 49.06,
#   'Humidity': 86,
#   'Cloudiness': 15,
#   'Wind': 14.34,
#   'Longitude': 49.6769,
#   'Latitude': 51.1786},
#  {'City Name': 'At-Bashi',
#   'Temperature': 43.86,
#   'Humidity': 43,
#   'Cloudiness': 98,
#   'Wind': 1.92,
#   'Longitude': 75.8106,
#   'Latitude': 41.1702},
#  {'City Name': 'Coyhaique',
#   'Temperature': 55.4,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind': 3.44,
#   'Longitude': -72.0662,
#   'Latitude': -45.5752},
#  {'City Name': 'Port Hardy',
#   'Temperature': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind': 3.44,
#   'Longitude': -127.4199,
#   'Latitude': 50.6996},
#  {'City Name': 'Marrakesh',
#   'Temperature': 69.8,
#   'Humidity': 52,
#   'Cloudiness': 75,
#   'Wind': 14.97,
#   'Longitude': -8.0083,
#   'Latitude': 31.6315},
#  {'City Name': 'Alekseyevsk',
#   'Temperature': 32.47,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind': 2.19,
#   'Longitude': 108.3492,
#   'Latitude': 57.8406},
#  {'City Name': 'São Miguel do Araguaia',
#   'Temperature': 88.02,
#   'Humidity': 46,
#   'Cloudiness': 6,
#   'Wind': 1.28,
#   'Longitude': -50.1628,
#   'Latitude': -13.275},
#  {'City Name': 'Alice Springs',
#   'Temperature': 46.4,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind': 5.75,
#   'Longitude': 133.8833,
#   'Latitude': -23.7},
#  {'City Name': 'Guerrero Negro',
#   'Temperature': 67.15,
#   'Humidity': 57,
#   'Cloudiness': 3,
#   'Wind': 15.05,
#   'Longitude': -114.0611,
#   'Latitude': 27.9769},
#  {'City Name': 'Nikel',
#   'Temperature': 32,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind': 16.11,
#   'Longitude': 30.222,
#   'Latitude': 69.4128},
#  {'City Name': 'Mékhé',
#   'Temperature': 96.8,
#   'Humidity': 28,
#   'Cloudiness': 0,
#   'Wind': 9.22,
#   'Longitude': -16.6218,
#   'Latitude': 15.1097},
#  {'City Name': 'Kayerkan',
#   'Temperature': 30.09,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind': 16.91,
#   'Longitude': 87.7602,
#   'Latitude': 69.3497},
#  {'City Name': 'Half Moon Bay',
#   'Temperature': 64,
#   'Humidity': 71,
#   'Cloudiness': 75,
#   'Wind': 9.22,
#   'Longitude': -122.4286,
#   'Latitude': 37.4636},
#  {'City Name': 'Salalah',
#   'Temperature': 82.18,
#   'Humidity': 75,
#   'Cloudiness': 17,
#   'Wind': 6.44,
#   'Longitude': 54.0924,
#   'Latitude': 17.0151},
#  {'City Name': 'Urengoy',
#   'Temperature': 32.45,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind': 6.73,
#   'Longitude': 78.3667,
#   'Latitude': 65.9667},
#  {'City Name': 'Clarence Town',
#   'Temperature': 53.01,
#   'Humidity': 93,
#   'Cloudiness': 0,
#   'Wind': 6.91,
#   'Longitude': 151.7833,
#   'Latitude': -32.5833},
#  {'City Name': 'Loreto',
#   'Temperature': 78.87,
#   'Humidity': 9,
#   'Cloudiness': 95,
#   'Wind': 3.78,
#   'Longitude': -101.9667,
#   'Latitude': 22.2667},
#  {'City Name': 'Mahon',
#   'Temperature': 59,
#   'Humidity': 72,
#   'Cloudiness': 0,
#   'Wind': 5.75,
#   'Longitude': 4.2658,
#   'Latitude': 39.8885},
#  {'City Name': 'Port Lincoln',
#   'Temperature': 57.56,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind': 4.03,
#   'Longitude': 135.8667,
#   'Latitude': -34.7333},
#  {'City Name': 'Raudeberg',
#   'Temperature': 37.99,
#   'Humidity': 72,
#   'Cloudiness': 68,
#   'Wind': 16.75,
#   'Longitude': 5.1352,
#   'Latitude': 61.9875},
#  {'City Name': 'Lithakia',
#   'Temperature': 60.8,
#   'Humidity': 77,
#   'Cloudiness': 40,
#   'Wind': 12.66,
#   'Longitude': 20.8333,
#   'Latitude': 37.7167},
#  {'City Name': 'The Valley',
#   'Temperature': 86,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind': 12.66,
#   'Longitude': -63.0578,
#   'Latitude': 18.217},
#  {'City Name': 'Faya',
#   'Temperature': 59,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind': 9.22,
#   'Longitude': 42.4509,
#   'Latitude': 18.3851},
#  {'City Name': 'Zholymbet',
#   'Temperature': 43.81,
#   'Humidity': 44,
#   'Cloudiness': 100,
#   'Wind': 11.74,
#   'Longitude': 71.7122,
#   'Latitude': 51.7433},
#  {'City Name': 'Nieuw Amsterdam',
#   'Temperature': 79,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind': 9.22,
#   'Longitude': -55.0833,
#   'Latitude': 5.8833},
#  {'City Name': 'Hailar',
#   'Temperature': 39.4,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind': 3.94,
#   'Longitude': 119.7,
#   'Latitude': 49.2},
#  {'City Name': 'Lüderitz',
#   'Temperature': 62.08,
#   'Humidity': 85,
#   'Cloudiness': 7,
#   'Wind': 5.28,
#   'Longitude': 15.1594,
#   'Latitude': -26.6481},
#  {'City Name': 'Havelock',
#   'Temperature': 66.2,
#   'Humidity': 59,
#   'Cloudiness': 75,
#   'Wind': 9.22,
#   'Longitude': -76.9013,
#   'Latitude': 34.8791},
#  {'City Name': 'Rio Grande',
#   'Temperature': 75.2,
#   'Humidity': 64,
#   'Cloudiness': 40,
#   'Wind': 8.05,
#   'Longitude': -52.0986,
#   'Latitude': -32.035},
#  {'City Name': 'Alyangula',
#   'Temperature': 69.8,
#   'Humidity': 100,
#   'Cloudiness': 100,
#   'Wind': 9.4,
#   'Longitude': 136.4192,
#   'Latitude': -13.8483},
#  {'City Name': 'Acapulco de Juárez',
#   'Temperature': 89.6,
#   'Humidity': 43,
#   'Cloudiness': 90,
#   'Wind': 9.22,
#   'Longitude': -99.8901,
#   'Latitude': 16.8634},
#  {'City Name': 'Honningsvåg',
#   'Temperature': 32.2,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind': 23.85,
#   'Longitude': 25.9704,
#   'Latitude': 70.9821},
#  {'City Name': 'Kawai',
#   'Temperature': 59,
#   'Humidity': 72,
#   'Cloudiness': 15,
#   'Wind': 1.14,
#   'Longitude': 135.85,
#   'Latitude': 34.2333},
#  {'City Name': 'Nānākuli',
#   'Temperature': 80.6,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind': 9.22,
#   'Longitude': -158.1547,
#   'Latitude': 21.3906},
#  {'City Name': 'Madison',
#   'Temperature': 68,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind': 10.36,
#   'Longitude': -86.5667,
#   'Latitude': 34.7334},
#  {'City Name': 'Görele',
#   'Temperature': 53.6,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind': 2.51,
#   'Longitude': 39.0031,
#   'Latitude': 41.0308},
#  {'City Name': 'Kumul',
#   'Temperature': 47.89,
#   'Humidity': 23,
#   'Cloudiness': 88,
#   'Wind': 6.69,
#   'Longitude': 93.45,
#   'Latitude': 42.8},
#  {'City Name': 'Mareeba',
#   'Temperature': 73.4,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind': 10.36,
#   'Longitude': 145.4333,
#   'Latitude': -17},
#  {'City Name': 'Port Hedland',
#   'Temperature': 68,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind': 6.91,
#   'Longitude': 118.5667,
#   'Latitude': -20.3167},
#  {'City Name': 'Kiryat Gat',
#   'Temperature': 68,
#   'Humidity': 100,
#   'Cloudiness': 4,
#   'Wind': 3.09,
#   'Longitude': 34.7642,
#   'Latitude': 31.61},
#  {'City Name': 'Porbandar',
#   'Temperature': 81.57,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind': 10.02,
#   'Longitude': 69.6093,
#   'Latitude': 21.6422},
#  {'City Name': 'Yarmouth',
#   'Temperature': 68,
#   'Humidity': 32,
#   'Cloudiness': 1,
#   'Wind': 18.41,
#   'Longitude': -70.2286,
#   'Latitude': 41.7057},
#  {'City Name': 'Torbay',
#   'Temperature': 53.6,
#   'Humidity': 35,
#   'Cloudiness': 40,
#   'Wind': 25.32,
#   'Longitude': -52.7314,
#   'Latitude': 47.6666},
#  {'City Name': 'Bluefield',
#   'Temperature': 48,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind': 5.75,
#   'Longitude': -81.2223,
#   'Latitude': 37.2698},
#  {'City Name': 'Conceição da Barra',
#   'Temperature': 78.93,
#   'Humidity': 72,
#   'Cloudiness': 55,
#   'Wind': 6.71,
#   'Longitude': -39.7322,
#   'Latitude': -18.5933},
#  {'City Name': 'Manbij',
#   'Temperature': 66.2,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind': 7.31,
#   'Longitude': 37.9549,
#   'Latitude': 36.5281},
#  {'City Name': 'Tuatapere',
#   'Temperature': 48,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind': 4,
#   'Longitude': 167.6833,
#   'Latitude': -46.1333},
#  {'City Name': 'Seminole',
#   'Temperature': 90,
#   'Humidity': 51,
#   'Cloudiness': 75,
#   'Wind': 14.97,
#   'Longitude': -81.2081,
#   'Latitude': 28.7086},
#  {'City Name': 'Vilhena',
#   'Temperature': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': -60.1458,
#   'Latitude': -12.7406},
#  {'City Name': 'Khovd',
#   'Temperature': 26.13,
#   'Humidity': 21,
#   'Cloudiness': 16,
#   'Wind': 15.86,
#   'Longitude': 91.6419,
#   'Latitude': 48.0056},
#  {'City Name': 'Asău',
#   'Temperature': 46,
#   'Humidity': 48,
#   'Cloudiness': 50,
#   'Wind': 3.56,
#   'Longitude': 26.4,
#   'Latitude': 46.4333},
#  {'City Name': 'Alwaye',
#   'Temperature': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind': 2.3,
#   'Longitude': 76.35,
#   'Latitude': 10.1167},
#  {'City Name': 'Wau',
#   'Temperature': 85.6,
#   'Humidity': 47,
#   'Cloudiness': 100,
#   'Wind': 3.6,
#   'Longitude': 27.9953,
#   'Latitude': 7.7029},
#  {'City Name': 'Santiago del Estero',
#   'Temperature': 76.28,
#   'Humidity': 51,
#   'Cloudiness': 18,
#   'Wind': 11.41,
#   'Longitude': -64.2615,
#   'Latitude': -27.7951},
#  {'City Name': 'Puerto Escondido',
#   'Temperature': 89.6,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind': 13.8,
#   'Longitude': -97.0667,
#   'Latitude': 15.85},
#  {'City Name': 'Cockburn Town',
#   'Temperature': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 40,
#   'Wind': 13.8,
#   'Longitude': -71.1419,
#   'Latitude': 21.4612},
#  {'City Name': 'Gladstone',
#   'Temperature': 64.4,
#   'Humidity': 77,
#   'Cloudiness': 68,
#   'Wind': 3.44,
#   'Longitude': 151.25,
#   'Latitude': -23.85},
#  {'City Name': 'Sioni',
#   'Temperature': 59,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind': 13.8,
#   'Longitude': 45.0239,
#   'Latitude': 41.9895},
#  {'City Name': 'Boende',
#   'Temperature': 73.06,
#   'Humidity': 90,
#   'Cloudiness': 67,
#   'Wind': 3.02,
#   'Longitude': 20.8667,
#   'Latitude': -0.2167},
#  {'City Name': 'Port Blair',
#   'Temperature': 81.64,
#   'Humidity': 75,
#   'Cloudiness': 4,
#   'Wind': 6.6,
#   'Longitude': 92.75,
#   'Latitude': 11.6667},
#  {'City Name': 'Ambilobe',
#   'Temperature': 73.89,
#   'Humidity': 92,
#   'Cloudiness': 13,
#   'Wind': 3.53,
#   'Longitude': 49.05,
#   'Latitude': -13.2},
#  {'City Name': 'Sembakung',
#   'Temperature': 73.4,
# ...
#   'Wind': 7.85,
#   'Longitude': -11.95,
#   'Latitude': 8.7833},
#  {'City Name': 'Rūdbār',
#   'Temperature': 77.79,
#   'Humidity': 9,
#   'Cloudiness': 3,
#   'Wind': 8.63,
#   'Longitude': 62.6,
#   'Latitude': 30.15},
#  {'City Name': 'Kaeo',
#   'Temperature': 54,
#   'Humidity': 96,
#   'Cloudiness': 21,
#   'Wind': 1.01,
#   'Longitude': 173.7833,
#   'Latitude': -35.1},
#  {'City Name': 'Porto Nacional',
#   'Temperature': 82.4,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind': 5.75,
#   'Longitude': -48.4172,
#   'Latitude': -10.7081},
#  {'City Name': 'Kysyl-Syr',
#   'Temperature': 33.3,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind': 5.21,
#   'Longitude': 122.7617,
#   'Latitude': 63.8986},
#  {'City Name': 'Cap-aux-Meules',
#   'Temperature': 41,
#   'Humidity': 75,
#   'Cloudiness': 10,
#   'Wind': 16.11,
#   'Longitude': -61.8597,
#   'Latitude': 47.3821},
#  {'City Name': 'Santa Cruz de la Sierra',
#   'Temperature': 68,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind': 5.75,
#   'Longitude': -63.1667,
#   'Latitude': -17.8},
#  {'City Name': 'Istok',
#   'Temperature': 48.2,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind': 3.44,
#   'Longitude': 20.4875,
#   'Latitude': 42.7808},
#  {'City Name': 'Çanakkale Province',
#   'Temperature': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind': 11.5,
#   'Longitude': 26.8333,
#   'Latitude': 40.0833},
#  {'City Name': 'College',
#   'Temperature': 51.8,
#   'Humidity': 32,
#   'Cloudiness': 20,
#   'Wind': 1.03,
#   'Longitude': -147.8028,
#   'Latitude': 64.8569},
#  {'City Name': 'Neiafu',
#   'Temperature': 75.2,
#   'Humidity': 88,
#   'Cloudiness': 40,
#   'Wind': 10.71,
#   'Longitude': -173.9833,
#   'Latitude': -18.65},
#  {'City Name': 'Vanavara',
#   'Temperature': 30.69,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind': 2.19,
#   'Longitude': 102.2797,
#   'Latitude': 60.34},
#  {'City Name': 'Tcholliré',
#   'Temperature': 83.37,
#   'Humidity': 54,
#   'Cloudiness': 100,
#   'Wind': 3.24,
#   'Longitude': 14.1698,
#   'Latitude': 8.4022},
#  {'City Name': 'Bandundu Province',
#   'Temperature': 71.24,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind': 3.67,
#   'Longitude': 17.3667,
#   'Latitude': -3.3167},
#  {'City Name': 'Makokou',
#   'Temperature': 70.47,
#   'Humidity': 92,
#   'Cloudiness': 95,
#   'Wind': 2.84,
#   'Longitude': 12.8642,
#   'Latitude': 0.5738},
#  {'City Name': 'Porto Santo',
#   'Temperature': 64.4,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind': 14.97,
#   'Longitude': -16.3415,
#   'Latitude': 33.072},
#  {'City Name': 'Arni',
#   'Temperature': 81.59,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind': 4.65,
#   'Longitude': 79.2833,
#   'Latitude': 12.6667},
#  {'City Name': 'Srīvardhan',
#   'Temperature': 80.11,
#   'Humidity': 73,
#   'Cloudiness': 94,
#   'Wind': 8.19,
#   'Longitude': 73.0167,
#   'Latitude': 18.0333},
#  {'City Name': 'Falam',
#   'Temperature': 62.91,
#   'Humidity': 27,
#   'Cloudiness': 100,
#   'Wind': 3.53,
#   'Longitude': 93.6833,
#   'Latitude': 22.9167},
#  {'City Name': 'Muroto-misakicho',
#   'Temperature': 60.4,
#   'Humidity': 74,
#   'Cloudiness': 6,
#   'Wind': 4.32,
#   'Longitude': 134.15,
#   'Latitude': 33.2833},
#  {'City Name': 'Arlit',
#   'Temperature': 92.71,
#   'Humidity': 7,
#   'Cloudiness': 4,
#   'Wind': 5.28,
#   'Longitude': 7.3853,
#   'Latitude': 18.7369},
#  {'City Name': 'Pozoblanco',
#   'Temperature': 60.8,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind': 8.05,
#   'Longitude': -4.8483,
#   'Latitude': 38.3791},
#  {'City Name': 'Kimbe',
#   'Temperature': 74.71,
#   'Humidity': 93,
#   'Cloudiness': 59,
#   'Wind': 1.86,
#   'Longitude': 150.1429,
#   'Latitude': -5.5502},
#  {'City Name': 'Luorong',
#   'Temperature': 72.43,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind': 7.18,
#   'Longitude': 109.6086,
#   'Latitude': 24.4058},
#  {'City Name': 'Marsaxlokk',
#   'Temperature': 61,
#   'Humidity': 63,
#   'Cloudiness': 0,
#   'Wind': 3.44,
#   'Longitude': 14.5431,
#   'Latitude': 35.8419},
#  {'City Name': 'Katobu',
#   'Temperature': 74.55,
#   'Humidity': 91,
#   'Cloudiness': 10,
#   'Wind': 2.86,
#   'Longitude': 122.5276,
#   'Latitude': -4.9408},
#  {'City Name': 'Wangou',
#   'Temperature': 30.79,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind': 2.75,
#   'Longitude': 126.9127,
#   'Latitude': 42.0623},
#  {'City Name': 'João Pinheiro',
#   'Temperature': 85.01,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind': 5.53,
#   'Longitude': -46.1725,
#   'Latitude': -17.7425},
#  {'City Name': 'Germantown',
#   'Temperature': 64.99,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind': 8.05,
#   'Longitude': -77.2717,
#   'Latitude': 39.1732},
#  {'City Name': 'Glendive',
#   'Temperature': 52,
#   'Humidity': 34,
#   'Cloudiness': 1,
#   'Wind': 8.03,
#   'Longitude': -104.7125,
#   'Latitude': 47.1053},
#  {'City Name': 'Farim',
#   'Temperature': 105.8,
#   'Humidity': 14,
#   'Cloudiness': 0,
#   'Wind': 6.91,
#   'Longitude': -15.2217,
#   'Latitude': 12.4839},
#  {'City Name': 'Pinheiro Machado',
#   'Temperature': 64,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind': 1.01,
#   'Longitude': -53.3811,
#   'Latitude': -31.5783},
#  {'City Name': 'La Rioja',
#   'Temperature': 64.4,
#   'Humidity': 45,
#   'Cloudiness': 0,
#   'Wind': 13.8,
#   'Longitude': -2.5,
#   'Latitude': 42.25},
#  {'City Name': 'Olafsvik',
#   'Temperature': 44.64,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind': 17.38,
#   'Longitude': -23.7142,
#   'Latitude': 64.8945},
#  {'City Name': 'Lorengau',
#   'Temperature': 81.01,
#   'Humidity': 76,
#   'Cloudiness': 92,
#   'Wind': 4.38,
#   'Longitude': 147.2712,
#   'Latitude': -2.0226},
#  {'City Name': 'Fegyvernek',
#   'Temperature': 50,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind': 4.61,
#   'Longitude': 20.5333,
#   'Latitude': 47.2667},
#  {'City Name': 'Lucapa',
#   'Temperature': 66.38,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind': 1.07,
#   'Longitude': 20.7447,
#   'Latitude': -8.4192},
#  {'City Name': 'São Desidério',
#   'Temperature': 85.06,
#   'Humidity': 56,
#   'Cloudiness': 93,
#   'Wind': 2.86,
#   'Longitude': -44.9733,
#   'Latitude': -12.3633},
#  {'City Name': 'Kandrian',
#   'Temperature': 75.94,
#   'Humidity': 86,
#   'Cloudiness': 18,
#   'Wind': 4.65,
#   'Longitude': 149.55,
#   'Latitude': -6.2167},
#  {'City Name': 'Verāval',
#   'Temperature': 80.98,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind': 12.95,
#   'Longitude': 70.3667,
#   'Latitude': 20.9},
#  {'City Name': 'Thinadhoo',
#   'Temperature': 82.78,
#   'Humidity': 69,
#   'Cloudiness': 5,
#   'Wind': 6.29,
#   'Longitude': 72.9333,
#   'Latitude': 0.5333},
#  {'City Name': 'Kampot',
#   'Temperature': 80.6,
#   'Humidity': 89,
#   'Cloudiness': 40,
#   'Wind': 6.91,
#   'Longitude': 104.1833,
#   'Latitude': 10.6167},
#  {'City Name': 'Hobyo',
#   'Temperature': 84.2,
#   'Humidity': 69,
#   'Cloudiness': 55,
#   'Wind': 12.84,
#   'Longitude': 48.5268,
#   'Latitude': 5.3505},
#  {'City Name': 'Palmerston',
#   'Temperature': 71.6,
#   'Humidity': 49,
#   'Cloudiness': 96,
#   'Wind': 4.61,
#   'Longitude': 130.9833,
#   'Latitude': -12.486},
#  {'City Name': 'Mulegé',
#   'Temperature': 82.47,
#   'Humidity': 20,
#   'Cloudiness': 54,
#   'Wind': 7.96,
#   'Longitude': -111.9833,
#   'Latitude': 26.8833},
#  {'City Name': 'Richards Bay',
#   'Temperature': 69.35,
#   'Humidity': 85,
#   'Cloudiness': 91,
#   'Wind': 11.5,
#   'Longitude': 32.0377,
#   'Latitude': -28.783},
#  {'City Name': 'Løpsmarka',
#   'Temperature': 37.4,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind': 13.8,
#   'Longitude': 14.4493,
#   'Latitude': 67.3134},
#  {'City Name': 'Aleksandro-Nevskiy',
#   'Temperature': 37.99,
#   'Humidity': 73,
#   'Cloudiness': 97,
#   'Wind': 14.74,
#   'Longitude': 40.2095,
#   'Latitude': 53.4751},
#  {'City Name': 'Belmonte',
#   'Temperature': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind': 13.8,
#   'Longitude': -38.8828,
#   'Latitude': -15.8631},
#  {'City Name': 'Belūsovka',
#   'Temperature': 23,
#   'Humidity': 54,
#   'Cloudiness': 0,
#   'Wind': 2.24,
#   'Longitude': 82.5239,
#   'Latitude': 50.1339},
#  {'City Name': 'Kiyasovo',
#   'Temperature': 44.01,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind': 1.99,
#   'Longitude': 53.1244,
#   'Latitude': 56.3491},
#  {'City Name': 'Kushmurun',
#   'Temperature': 48.63,
#   'Humidity': 45,
#   'Cloudiness': 84,
#   'Wind': 14.58,
#   'Longitude': 64.6311,
#   'Latitude': 52.4503},
#  {'City Name': 'Erciş',
#   'Temperature': 46.4,
#   'Humidity': 61,
#   'Cloudiness': 0,
#   'Wind': 1.14,
#   'Longitude': 43.3586,
#   'Latitude': 39.0287},
#  {'City Name': 'Makhachkala',
#   'Temperature': 46.4,
#   'Humidity': 87,
#   'Cloudiness': 2,
#   'Wind': 4.47,
#   'Longitude': 47.5024,
#   'Latitude': 42.9764},
#  {'City Name': 'Uglegorsk',
#   'Temperature': 31.91,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind': 2.53,
#   'Longitude': 142.0333,
#   'Latitude': 49.0833},
#  {'City Name': 'Amboasary',
#   'Temperature': 75.2,
#   'Humidity': 83,
#   'Cloudiness': 40,
#   'Wind': 13.8,
#   'Longitude': 46.3833,
#   'Latitude': -25.0333},
#  {'City Name': 'Batagay-Alyta',
#   'Temperature': 16.5,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind': 5.68,
#   'Longitude': 130.4114,
#   'Latitude': 67.8006},
#  {'City Name': 'Cordele',
#   'Temperature': 63,
#   'Humidity': 94,
#   'Cloudiness': 90,
#   'Wind': 12.66,
#   'Longitude': -83.7824,
#   'Latitude': 31.9635},
#  {'City Name': 'Aklavik',
#   'Temperature': 33.8,
#   'Humidity': 60,
#   'Cloudiness': 20,
#   'Wind': 2.3,
#   'Longitude': -135.0107,
#   'Latitude': 68.2191},
#  {'City Name': 'Miyako',
#   'Temperature': 51.6,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind': 2.66,
#   'Longitude': 141.9525,
#   'Latitude': 39.6367},
#  {'City Name': 'Tura',
#   'Temperature': 75.25,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind': 3.51,
#   'Longitude': 90.2201,
#   'Latitude': 25.5198},
#  {'City Name': 'Taltal',
#   'Temperature': 64.72,
#   'Humidity': 71,
#   'Cloudiness': 49,
#   'Wind': 4.76,
#   'Longitude': -70.4833,
#   'Latitude': -25.4},
#  {'City Name': 'Sabang',
#   'Temperature': 82.9,
#   'Humidity': 72,
#   'Cloudiness': 100,
#   'Wind': 16.24,
#   'Longitude': 95.3214,
#   'Latitude': 5.8933},
#  {'City Name': 'Partizansk',
#   'Temperature': 33.48,
#   'Humidity': 71,
#   'Cloudiness': 0,
#   'Wind': 3.04,
#   'Longitude': 133.1339,
#   'Latitude': 43.1258},
#  {'City Name': 'Sabancuy',
#   'Temperature': 96.55,
#   'Humidity': 41,
#   'Cloudiness': 97,
#   'Wind': 0.31,
#   'Longitude': -91.1833,
#   'Latitude': 18.9667},
#  {'City Name': 'Iranshahr',
#   'Temperature': 91.4,
#   'Humidity': 19,
#   'Cloudiness': 0,
#   'Wind': 4.61,
#   'Longitude': 60.6848,
#   'Latitude': 27.2025},
#  {'City Name': 'Margate',
#   'Temperature': 46,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind': 4,
#   'Longitude': 1.3862,
#   'Latitude': 51.3813},
#  {'City Name': 'Beyneu',
#   'Temperature': 62.37,
#   'Humidity': 39,
#   'Cloudiness': 100,
#   'Wind': 5.97,
#   'Longitude': 55.2,
#   'Latitude': 45.3167},
#  {'City Name': 'Wakkanai',
#   'Temperature': 33.98,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind': 9.98,
#   'Longitude': 141.6739,
#   'Latitude': 45.4094},
#  {'City Name': 'Lodwar',
#   'Temperature': 87.46,
#   'Humidity': 44,
#   'Cloudiness': 75,
#   'Wind': 18.45,
#   'Longitude': 35.5973,
#   'Latitude': 3.1191},
#  {'City Name': 'Camapuã',
#   'Temperature': 93.67,
#   'Humidity': 17,
#   'Cloudiness': 5,
#   'Wind': 3.65,
#   'Longitude': -54.0439,
#   'Latitude': -19.5314},
#  {'City Name': 'Løding',
#   'Temperature': 37.4,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind': 13.8,
#   'Longitude': 14.75,
#   'Latitude': 67.3},
#  {'City Name': 'Clyde River',
#   'Temperature': 17.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind': 9.22,
#   'Longitude': -68.5914,
#   'Latitude': 70.4692},
#  {'City Name': 'Shwebo',
#   'Temperature': 88.14,
#   'Humidity': 32,
#   'Cloudiness': 5,
#   'Wind': 4.56,
#   'Longitude': 95.7,
#   'Latitude': 22.5667},
#  {'City Name': 'Gravdal',
#   'Temperature': 35.38,
#   'Humidity': 74,
#   'Cloudiness': 95,
#   'Wind': 16.44,
#   'Longitude': 13.5031,
#   'Latitude': 68.1214},
#  {'City Name': 'Panama City',
#   'Temperature': 89.6,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind': 11.5,
#   'Longitude': -79.5197,
#   'Latitude': 8.9936},
#  {'City Name': 'Along',
#   'Temperature': 65.46,
#   'Humidity': 68,
#   'Cloudiness': 64,
#   'Wind': 2.44,
#   'Longitude': 94.7667,
#   'Latitude': 28.1667},
#  {'City Name': 'Poum',
#   'Temperature': 78.35,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind': 15.23,
#   'Longitude': 164.0167,
#   'Latitude': -20.2333},
#  {'City Name': 'Shimokizukuri',
#   'Temperature': 50,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind': 4,
#   'Longitude': 140.3861,
#   'Latitude': 40.8061},
#  {'City Name': 'Carndonagh',
#   'Temperature': 50.63,
#   'Humidity': 70,
#   'Cloudiness': 6,
#   'Wind': 6.96,
#   'Longitude': -7.2667,
#   'Latitude': 55.25},
#  {'City Name': 'Quepos',
#   'Temperature': 82.4,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind': 10.36,
#   'Longitude': -84.1652,
#   'Latitude': 9.4236},
#  {'City Name': 'Portland',
#   'Temperature': 50,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind': 9.22,
#   'Longitude': -122.6762,
#   'Latitude': 45.5234},
#  {'City Name': 'Tual',
#   'Temperature': 84.49,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind': 16.06,
#   'Longitude': 132.75,
#   'Latitude': -5.6667},
#  {'City Name': 'Harrison',
#   'Temperature': 81,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind': 13.8,
#   'Longitude': -89.0436,
#   'Latitude': 30.4091},
#  {'City Name': 'Curuguaty',
#   'Temperature': 68.23,
#   'Humidity': 88,
#   'Cloudiness': 100,
#   'Wind': 2.28,
#   'Longitude': -55.6945,
#   'Latitude': -24.4694},
#  {'City Name': 'Martapura',
#   'Temperature': 78.8,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind': 2.3,
#   'Longitude': 114.85,
#   'Latitude': -3.4167},
#  {'City Name': 'Coahuayana Viejo',
#   'Temperature': 86,
#   'Humidity': 30,
#   'Cloudiness': 40,
#   'Wind': 8.23,
#   'Longitude': -103.6833,
#   'Latitude': 18.7333},
#  {'City Name': 'Joshīmath',
#   'Temperature': 46.18,
#   'Humidity': 52,
#   'Cloudiness': 86,
#   'Wind': 10.83,
#   'Longitude': 79.5667,
#   'Latitude': 30.5667},
#  {'City Name': 'Mandalgovi',
#   'Temperature': 48.13,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind': 4.7,
#   'Longitude': 106.2708,
#   'Latitude': 45.7625},
#  {'City Name': 'Mirador',
#   'Temperature': 81.43,
#   'Humidity': 87,
#   'Cloudiness': 82,
#   'Wind': 4,
#   'Longitude': -44.3631,
#   'Latitude': -6.3708},
#  {'City Name': "Ust'-Kulom",
#   'Temperature': 43.63,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind': 6.46,
#   'Longitude': 53.6902,
#   'Latitude': 61.6864},
#  {'City Name': 'Blackfoot',
#   'Temperature': 57.99,
#   'Humidity': 28,
#   'Cloudiness': 100,
#   'Wind': 7,
#   'Longitude': -112.345,
#   'Latitude': 43.1905},
#  {'City Name': 'Kānodar',
#   'Temperature': 82.74,
#   'Humidity': 35,
#   'Cloudiness': 17,
#   'Wind': 4.38,
#   'Longitude': 72.3833,
#   'Latitude': 24.1},
#  {'City Name': 'Óbidos',
#   'Temperature': 86.02,
#   'Humidity': 69,
#   'Cloudiness': 56,
#   'Wind': 4.5,
#   'Longitude': -55.5181,
#   'Latitude': -1.9175},
#  {'City Name': 'Goderich',
#   'Temperature': 57.2,
#   'Humidity': 35,
#   'Cloudiness': 100,
#   'Wind': 6.91,
#   'Longitude': -81.7165,
#   'Latitude': 43.7501},
#  {'City Name': 'Arucas',
#   'Temperature': 69.01,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind': 16.11,
#   'Longitude': -15.5233,
#   'Latitude': 28.1198},
#  {'City Name': 'Ponca City',
#   'Temperature': 66.99,
#   'Humidity': 45,
#   'Cloudiness': 20,
#   'Wind': 11.5,
#   'Longitude': -97.0856,
#   'Latitude': 36.707},
#  {'City Name': 'Bubaque',
#   'Temperature': 78.37,
#   'Humidity': 69,
#   'Cloudiness': 15,
#   'Wind': 22.21,
#   'Longitude': -15.8333,
#   'Latitude': 11.2833},
#  {'City Name': 'Uray',
#   'Temperature': 41.86,
#   'Humidity': 80,
#   'Cloudiness': 100,
#   'Wind': 5.28,
#   'Longitude': 64.7758,
#   'Latitude': 60.1247},
#  {'City Name': 'Gold Coast',
#   'Temperature': 57,
#   'Humidity': 94,
#   'Cloudiness': 13,
#   'Wind': 4.25,
#   'Longitude': 153.4333,
#   'Latitude': -28},
#  {'City Name': 'Lincoln',
#   'Temperature': 57.2,
#   'Humidity': 44,
#   'Cloudiness': 1,
#   'Wind': 8.05,
#   'Longitude': -96.667,
#   'Latitude': 40.8},
#  {'City Name': 'Nalobikha',
#   'Temperature': 34.09,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind': 3.56,
#   'Longitude': 84.6039,
#   'Latitude': 53.2006},
#  {'City Name': 'Sterling',
#   'Temperature': 64,
#   'Humidity': 31,
#   'Cloudiness': 90,
#   'Wind': 8.05,
#   'Longitude': -77.4286,
#   'Latitude': 39.0062},
#  {'City Name': 'São José da Coroa Grande',
#   'Temperature': 82.06,
#   'Humidity': 72,
#   'Cloudiness': 26,
#   'Wind': 7.94,
#   'Longitude': -35.1478,
#   'Latitude': -8.8978},
#  {'City Name': 'Maputo',
#   'Temperature': 75,
#   'Humidity': 83,
#   'Cloudiness': 20,
#   'Wind': 4.61,
#   'Longitude': 32.5892,
#   'Latitude': -25.9653}]

# %%
# all_info = []
# df = pd.DataFrame()

# for city in cities: 
#     url = base_url + city 
#     city_weather = requests.get(url).json()
#     try:
#         city_lon = city_weather["coord"]["lon"]
#         city_lan = city_weather["coord"]["lat"]
#         city_temperature_min = city_weather["main"]["temp_min"]
#         city_temperature_max = city_weather["main"]["temp_max"]
#         city_humidity = city_weather["main"]["humidity"]
#         city_cloud = city_weather["clouds"]["all"]
#         city_wind = city_weather["wind"]["speed"]
        
        
#         all_info.append({"Lon": city_lon, "Lat": city_lan})
#         all_info.append({"Min Temp": city_temperature_min, "Max temp": city_temperature_max})
#         all_info.append({"Humidity": city_humudity})
#         all_info.append({"Cloudiness": city_cloud})
#         all_info.append({"Wind": city_wind})
        
#         append.temp_df(df)
#     except Exception as e:
#         print(e)

# city_info

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_df = pd.DataFrame(city_info)
# weather_df

new_output = "output_data/new_cities.csv"
weather_df.to_csv(new_output, index_label= "ID")

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df
# Out:
#                     City Name  Temperature  Humidity  Cloudiness   Wind  \
# 0                      Anloga        71.60        94          90  17.27
# 1                       Opuwo        73.15        39          81   3.27
# 2        Vila Franca do Campo        59.00        82          40  16.11
# 3                       Qeshm        82.40        65          29   6.91
# 4                       Kolín        48.20        49           0   5.75
# ..                        ...          ...       ...         ...    ...
# 667                   Lincoln        57.20        44           1   8.05
# 668                 Nalobikha        34.09        83         100   3.56
# 669                  Sterling        64.00        31          90   8.05
# 670  São José da Coroa Grande        82.06        72          26   7.94
# 671                    Maputo        75.00        83          20   4.61
#
#      Longitude  Latitude
# 0       0.8973    5.7947
# 1      13.8400  -18.0607
# 2     -25.4333   37.7167
# 3      56.2719   26.9581
# 4      15.2006   50.0281
# ..         ...       ...
# 667   -96.6670   40.8000
# 668    84.6039   53.2006
# 669   -77.4286   39.0062
# 670   -35.1478   -8.8978
# 671    32.5892  -25.9653
#
# [672 rows x 7 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
# Not applicable

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
marker_size=12
plt.scatter(weather_df['Latitude'],weather_df['Temperature'],s=25, color="brown")
# Plot beautification
plt.title('Latitude vs. Temperature Plot',fontsize =8)
plt.xlabel('Latitude',fontsize =8)
plt.ylabel('Temperature',fontsize =8)

# Print test
plt.show()

plt.savefig('Temp vs.Lat.png')

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
marker_size=12
plt.scatter(weather_df['Latitude'],weather_df['Humidity'],s=25, color="brown")
# Plot beautification
plt.title('Latitude vs. Humidity',fontsize =8)
plt.xlabel('Humidity',fontsize =8)
plt.ylabel('Latitude',fontsize =8)

# Print test
plt.show()

plt.savefig('Hum vs.Lat.png')

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
marker_size=12
plt.scatter(weather_df['Latitude'],weather_df['Cloudiness'],s=25, color="brown")
# Plot beautification
plt.title('Latitude vs. Cloudiness',fontsize =8)
plt.xlabel('Latitude',fontsize =8)
plt.ylabel('Cloudiness',fontsize =8)

# Print test
plt.show()

plt.savefig('Clou vs.Lat.png')

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
marker_size=12
plt.scatter(weather_df['Latitude'],weather_df['Wind'],s=25, color="brown")
# Plot beautification
plt.title('Latitude vs. Wind',fontsize =8)
plt.xlabel('Latitude',fontsize =8)
plt.ylabel('Wind',fontsize =8)

# Print test
plt.show()

plt.savefig('Win vs.Lat.png')

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
